# %%
# !pip install feedparser
# !pip install owlready2
# !pip install spade
# Out:
# Requirement already satisfied: feedparser in d:\anaconda\envs\sin\lib\site-packages (6.0.11)
# Requirement already satisfied: sgmllib3k in d:\anaconda\envs\sin\lib\site-packages (from feedparser) (1.0.0)
# Requirement already satisfied: owlready2 in d:\anaconda\envs\sin\lib\site-packages (0.47)
# Requirement already satisfied: spade in d:\anaconda\envs\sin\lib\site-packages (4.0.2)
# Requirement already satisfied: slixmpp==1.8.5 in d:\anaconda\envs\sin\lib\site-packages (from spade) (1.8.5)
# Requirement already satisfied: aiohttp>=3.10.4 in d:\anaconda\envs\sin\lib\site-packages (from spade) (3.10.4)
# Requirement already satisfied: aiohttp_jinja2==1.6 in d:\anaconda\envs\sin\lib\site-packages (from spade) (1.6)
# Requirement already satisfied: jinja2==3.0.3 in d:\anaconda\envs\sin\lib\site-packages (from spade) (3.0.3)
# Requirement already satisfied: jinja2-time==0.2.0 in d:\anaconda\envs\sin\lib\site-packages (from spade) (0.2.0)
# Requirement already satisfied: timeago==1.0.16 in d:\anaconda\envs\sin\lib\site-packages (from spade) (1.0.16)
# Requirement already satisfied: singletonify==0.2.4 in d:\anaconda\envs\sin\lib\site-packages (from spade) (0.2.4)
# Requirement already satisfied: pytz==2022.1 in d:\anaconda\envs\sin\lib\site-packages (from spade) (2022.1)
# Requirement already satisfied: pyjabber>=0.1.9 in d:\anaconda\envs\sin\lib\site-packages (from spade) (0.2.3)
# Requirement already satisfied: rich>=13.9.4 in d:\anaconda\envs\sin\lib\site-packages (from spade) (13.9.4)
# Requirement already satisfied: winloop>=0.1.7 in d:\anaconda\envs\sin\lib\site-packages (from spade) (0.1.8)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\envs\sin\lib\site-packages (from jinja2==3.0.3->spade) (3.0.2)
# Requirement already satisfied: arrow in d:\anaconda\envs\sin\lib\site-packages (from jinja2-time==0.2.0->spade) (1.3.0)
# Requirement already satisfied: aiodns>=1.0 in d:\anaconda\envs\sin\lib\site-packages (from slixmpp==1.8.5->spade) (3.2.0)
# Requirement already satisfied: pyasn1 in d:\anaconda\envs\sin\lib\site-packages (from slixmpp==1.8.5->spade) (0.6.1)
# Requirement already satisfied: pyasn1_modules in d:\anaconda\envs\sin\lib\site-packages (from slixmpp==1.8.5->spade) (0.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\anaconda\envs\sin\lib\site-packages (from aiohttp>=3.10.4->spade) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\anaconda\envs\sin\lib\site-packages (from aiohttp>=3.10.4->spade) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda\envs\sin\lib\site-packages (from aiohttp>=3.10.4->spade) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda\envs\sin\lib\site-packages (from aiohttp>=3.10.4->spade) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda\envs\sin\lib\site-packages (from aiohttp>=3.10.4->spade) (6.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\anaconda\envs\sin\lib\site-packages (from aiohttp>=3.10.4->spade) (1.18.3)
# Requirement already satisfied: click==8.1.7 in d:\anaconda\envs\sin\lib\site-packages (from pyjabber>=0.1.9->spade) (8.1.7)
# Requirement already satisfied: cryptography==43.0.1 in d:\anaconda\envs\sin\lib\site-packages (from pyjabber>=0.1.9->spade) (43.0.1)
# Requirement already satisfied: loguru==0.7.2 in d:\anaconda\envs\sin\lib\site-packages (from pyjabber>=0.1.9->spade) (0.7.2)
# Requirement already satisfied: pyyaml~=6.0.2 in d:\anaconda\envs\sin\lib\site-packages (from pyjabber>=0.1.9->spade) (6.0.2)
# Requirement already satisfied: colorama in d:\anaconda\envs\sin\lib\site-packages (from click==8.1.7->pyjabber>=0.1.9->spade) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in d:\anaconda\envs\sin\lib\site-packages (from cryptography==43.0.1->pyjabber>=0.1.9->spade) (1.17.1)
# Requirement already satisfied: win32-setctime>=1.0.0 in d:\anaconda\envs\sin\lib\site-packages (from loguru==0.7.2->pyjabber>=0.1.9->spade) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda\envs\sin\lib\site-packages (from rich>=13.9.4->spade) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda\envs\sin\lib\site-packages (from rich>=13.9.4->spade) (2.19.1)
# Requirement already satisfied: pycares>=4.0.0 in d:\anaconda\envs\sin\lib\site-packages (from aiodns>=1.0->slixmpp==1.8.5->spade) (4.5.0)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\envs\sin\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->spade) (0.1.2)
# Requirement already satisfied: idna>=2.0 in d:\anaconda\envs\sin\lib\site-packages (from yarl<2.0,>=1.0->aiohttp>=3.10.4->spade) (3.10)
# Requirement already satisfied: propcache>=0.2.0 in d:\anaconda\envs\sin\lib\site-packages (from yarl<2.0,>=1.0->aiohttp>=3.10.4->spade) (0.3.1)
# Requirement already satisfied: python-dateutil>=2.7.0 in d:\anaconda\envs\sin\lib\site-packages (from arrow->jinja2-time==0.2.0->spade) (2.9.0.post0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in d:\anaconda\envs\sin\lib\site-packages (from arrow->jinja2-time==0.2.0->spade) (2.9.0.20241206)
# Requirement already satisfied: pycparser in d:\anaconda\envs\sin\lib\site-packages (from cffi>=1.12->cryptography==43.0.1->pyjabber>=0.1.9->spade) (2.22)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\sin\lib\site-packages (from python-dateutil>=2.7.0->arrow->jinja2-time==0.2.0->spade) (1.17.0)

# %%
from IPython.display import display, HTML

html_content = """
<style>
    .title {
        font-size: 24px;
        font-weight: bold;
        color: #00aaff;
        text-align: center;
        margin-bottom: 10px;
    }
    .section {
        font-size: 18px;
        font-weight: bold;
        color: #000;
        background-color: #88ccff;
        padding: 5px;
        border-radius: 5px;
        margin-top: 10px;
    }
    .content {
        font-size: 16px;
        color: #000;
        line-height: 1.5;
        background-color: #eef;
        padding: 5px;
        border-radius: 5px;
    }
    .code {
        background-color: #222;
        padding: 10px;
        border-radius: 5px;
        font-family: monospace;
        color: #00ff00;
    }
</style>

<div class='title'>🕵️‍♂️ EJEMPLO 1: Agente 1 como Coordinador de Noticias 📰</div>

<div class='section'>🔍 ¿Qué hace este código?</div>
<div class='content'>
    Este código implementa un sistema multiagente en Python con SPADE donde <b>el Agente 1</b> actúa como un coordinador que solicita información de noticias a otros agentes (<b>Agente 2, Agente 3 y Agente 4</b>), los cuales consultan diferentes fuentes RSS.<br><br>
    <b>Flujo del programa:</b>
    <ul>
        <li>El usuario ingresa un término de búsqueda.</li>
        <li>El Agente 1 envía la solicitud a los otros tres agentes.</li>
        <li>Cada agente busca coincidencias en su respectivo feed RSS.</li>
        <li>Si encuentran noticias relevantes, las envían de vuelta al Agente 1.</li>
        <li>El Agente 1 recopila y muestra un resumen con los resultados obtenidos.</li>
    </ul>
</div>

<div class='section'>📌 Notas</div>
<div class='content'>
    - <b>El Agente 1 sigue funcionando indefinidamente</b>, solicitando más búsquedas hasta que se detenga manualmente. <br/>
    - Si ningún agente encuentra coincidencias, simplemente se muestra un mensaje indicando que no hubo resultados. <br/>
    - Se puede extender este sistema para incluir más fuentes de noticias o mejorar la ontología utilizada.
</div>
"""

display(HTML(html_content))
# Out:
# <style>
#     .title {
#         font-size: 24px;
#         font-weight: bold;
#         color: #00aaff;
#         text-align: center;
#         margin-bottom: 10px;
#     }
#     .section {
#         font-size: 18px;
#         font-weight: bold;
#         color: #000;
#         background-color: #88ccff;
#         padding: 5px;
#         border-radius: 5px;
#         margin-top: 10px;
#     }
#     .content {
#         font-size: 16px;
#         color: #000;
#         line-height: 1.5;
#         background-color: #eef;
#         padding: 5px;
#         border-radius: 5px;
#     }
#     .code {
#         background-color: #222;
#         padding: 10px;
#         border-radius: 5px;
#         font-family: monospace;
#         color: #00ff00;
#     }
# </style>
#
# <div class='title'>🕵️‍♂️ EJEMPLO 1: Agente 1 como Coordinador de Noticias 📰</div>
#
# <div class='section'>🔍 ¿Qué hace este código?</div>
# <div class='content'>
#     Este código implementa un sistema multiagente en Python con SPADE donde <b>el Agente 1</b> actúa como un coordinador que solicita información de noticias a otros agentes (<b>Agente 2, Agente 3 y Agente 4</b>), los cuales consultan diferentes fuentes RSS.<br><br>
#     <b>Flujo del programa:</b>
#     <ul>
#         <li>El usuario ingresa un término de búsqueda.</li>
#         <li>El Agente 1 envía la solicitud a los otros tres agentes.</li>
#         <li>Cada agente busca coincidencias en su respectivo feed RSS.</li>
#         <li>Si encuentran noticias relevantes, las envían de vuelta al Agente 1.</li>
#         <li>El Agente 1 recopila y muestra un resumen con los resultados obtenidos.</li>
#     </ul>
# </div>
#
# <div class='section'>📌 Notas</div>
# <div class='content'>
#     - <b>El Agente 1 sigue funcionando indefinidamente</b>, solicitando más búsquedas hasta que se detenga manualmente. <br/>
#     - Si ningún agente encuentra coincidencias, simplemente se muestra un mensaje indicando que no hubo resultados. <br/>
#     - Se puede extender este sistema para incluir más fuentes de noticias o mejorar la ontología utilizada.
# </div>

# %%
import asyncio
import spade
from spade.agent import Agent
from spade.behaviour import CyclicBehaviour
from spade.template import Template
from spade.message import Message
from owlready2 import get_ontology
import feedparser

# ---------------------------
# Agente 1: Coordinador e interfaz (solicita y resume resultados de 3 agentes)
# ---------------------------
class Agent1(Agent):
    async def setup(self):
        print(f"Agent1 iniciado: {self.jid}")
        self.add_behaviour(SearchAndCoordinateBehaviour())

class SearchAndCoordinateBehaviour(CyclicBehaviour):
    async def run(self):
        search_term = input("Ingrese la cadena de búsqueda de noticias: ")
        
        recipients = [
            "agent2_brivaro@gtirouter.dsic.upv.es",
            "agent3_brivaro@gtirouter.dsic.upv.es",
            "agent4_brivaro@gtirouter.dsic.upv.es" 
        ]
        
        responses = []
        
        for recipient in recipients:
            msg = Message(to=recipient)
            msg.set_metadata("performative", "request")
            msg.body = search_term
            await self.send(msg)
            print(f"Solicitud enviada a {recipient}.")

        # Esperar respuestas de cada agente (timeout 15 segundos)
        for _ in recipients:
            response = await self.receive(timeout=15)
            if response:
                responses.append((str(response.sender), response.body))
                print(f"Respuesta recibida de {response.sender}:")
                print(response.body)
            else:
                print("No se recibió respuesta en el tiempo esperado.")

        # Resumir y mostrar todas las respuestas al usuario
        print("\n--- Resumen de noticias de todos los agentes ---")
        for sender, resp in responses:
            print(f"Desde {sender}:")
            print(resp)
            print("------------------------------------------------")
        print("\n")

        # Si se quiere permitir otra búsqueda, se puede comentar la siguiente línea:
        # self.kill()  # Termina el comportamiento para detener el agente

# ---------------------------
# Agente base para buscadores que consulta un feed RSS y actualiza la ontología rNews
# ---------------------------
class BaseRSSAgent(Agent):
    def __init__(self, jid, password, feed_url, ontology_url, *args, **kwargs):
        super().__init__(jid, password, *args, **kwargs)
        self.feed_url = feed_url
        self.ontology_url = ontology_url

    async def setup(self):
        print(f"{self.__class__.__name__} iniciado: {self.jid}")
        try:
            self.onto = get_ontology(self.ontology_url).load()
            print(f"{self.__class__.__name__}: Ontología rNews cargada.")
        except Exception as e:
            print(f"{self.__class__.__name__}: Error al cargar la ontología:", e)
        
        # Registrar el comportamiento con un template que filtre mensajes con performative "request"
        template = Template(metadata={"performative": "request"})
        self.add_behaviour(RSSSearchBehaviour(self.feed_url), template)

# ---------------------------
# Comportamiento común para agentes que consultan un feed RSS
# ---------------------------
class RSSSearchBehaviour(CyclicBehaviour):
    def __init__(self, feed_url, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.feed_url = feed_url

    async def run(self):
        msg = await self.receive(timeout=10)
        if msg and msg.get_metadata("performative") == "request":
            search_term = msg.body
            print(f"{self.agent.__class__.__name__}: Solicitud para buscar '{search_term}' recibida de {msg.sender}")

            feed = feedparser.parse(self.feed_url)
            matching_entries = []
            for entry in feed.entries:
                # Buscar en el título o resumen (si existe)
                summary = entry.get("summary", "")
                if search_term.lower() in entry.title.lower() or search_term.lower() in summary.lower():
                    matching_entries.append(entry)

            result_text = f"Se encontraron {len(matching_entries)} noticias para '{search_term}':\n"
            for entry in matching_entries:
                result_text += f"- {entry.title}\n"

            # Preparar y enviar la respuesta
            reply = msg.make_reply()
            reply.set_metadata("performative", "inform")
            reply.body = result_text
            await self.send(reply)
            print(f"{self.agent.__class__.__name__}: Respuesta enviada al solicitante.")
        await asyncio.sleep(1)

# ---------------------------
# Agentes consultores (cada uno con un feed RSS distinto)
# ---------------------------
class Agent2(BaseRSSAgent):
    pass  # Usa la implementación base; su feed se definirá al instanciar

class Agent3(BaseRSSAgent):
    pass

class Agent4(BaseRSSAgent):
    pass

# %%
# ---------------------------
# Función principal para iniciar los agentes
# ---------------------------
password = "SPADE"

ontology_url = "http://dev.iptc.org/files/rNews/rnews_1.0_draft3_rdfxml.owl"

feed_url_agent2 = "http://feeds.bbci.co.uk/news/rss.xml"   # BBC News
feed_url_agent3 = "https://rss.nytimes.com/services/xml/rss/nyt/HomePage.xml"  # NYTimes
feed_url_agent4 = "https://www.cnet.com/rss/news/"  # CNET News

agent1_jid = "agent1_brivaro@gtirouter.dsic.upv.es"
agent2_jid = "agent2_brivaro@gtirouter.dsic.upv.es"
agent3_jid = "agent3_brivaro@gtirouter.dsic.upv.es"
agent4_jid = "agent4_brivaro@gtirouter.dsic.upv.es"

agent1 = Agent1(agent1_jid, password)
agent2 = Agent2(agent2_jid, password, feed_url_agent2, ontology_url)
agent3 = Agent3(agent3_jid, password, feed_url_agent3, ontology_url)
agent4 = Agent4(agent4_jid, password, feed_url_agent4, ontology_url)

# Iniciar los agentes con auto-registro en el servidor XMPP
await agent2.start(auto_register=True)
await agent3.start(auto_register=True)
await agent4.start(auto_register=True)
await asyncio.sleep(3) # Esperar un poco para asegurar que los agentes están listos
await agent1.start(auto_register=True)

# Esperar a que Agent1 termine su comportamiento (la búsqueda)
while agent1.is_alive():
    await asyncio.sleep(1)

await agent1.stop()
await agent2.stop()
await agent3.stop()
await agent4.stop()
print("Todos los agentes han sido detenidos.")
# Out:
# Agent2 iniciado: agent2_brivaro@gtirouter.dsic.upv.es
# Agent2: Ontología rNews cargada.
# Agent3 iniciado: agent3_brivaro@gtirouter.dsic.upv.es
# Agent3: Ontología rNews cargada.
# Agent4 iniciado: agent4_brivaro@gtirouter.dsic.upv.es
# Agent4: Ontología rNews cargada.
# Agent1 iniciado: agent1_brivaro@gtirouter.dsic.upv.es
# Solicitud enviada a agent2_brivaro@gtirouter.dsic.upv.es.
# Solicitud enviada a agent3_brivaro@gtirouter.dsic.upv.es.
# Solicitud enviada a agent4_brivaro@gtirouter.dsic.upv.es.
# Agent2: Solicitud para buscar 'survivors' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent2: Respuesta enviada al solicitante.
# Agent3: Solicitud para buscar 'survivors' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent3: Respuesta enviada al solicitante.
# Agent4: Solicitud para buscar 'survivors' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent4: Respuesta enviada al solicitante.
# Respuesta recibida de agent2_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 1 noticias para 'survivors':
# - Myanmar quake toll passes 1,600 as people dig for survivors with bare hands
#
# Respuesta recibida de agent3_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 2 noticias para 'survivors':
# - Myanmar Earthquake Toll Surpasses 1,600 Dead Amid Search for Survivors
# - Search for Survivors at Collapsed Bangkok Building
#
# Respuesta recibida de agent4_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'survivors':
#
#
# --- Resumen de noticias de todos los agentes ---
# Desde agent2_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 1 noticias para 'survivors':
# - Myanmar quake toll passes 1,600 as people dig for survivors with bare hands
#
# ------------------------------------------------
# Desde agent3_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 2 noticias para 'survivors':
# - Myanmar Earthquake Toll Surpasses 1,600 Dead Amid Search for Survivors
# - Search for Survivors at Collapsed Bangkok Building
#
# ------------------------------------------------
# Desde agent4_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'survivors':
#
# ------------------------------------------------
#
#
# Solicitud enviada a agent2_brivaro@gtirouter.dsic.upv.es.
# Solicitud enviada a agent3_brivaro@gtirouter.dsic.upv.es.
# Solicitud enviada a agent4_brivaro@gtirouter.dsic.upv.es.
# Agent2: Solicitud para buscar 'hands' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent2: Respuesta enviada al solicitante.
# Agent3: Solicitud para buscar 'hands' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent3: Respuesta enviada al solicitante.
# Agent4: Solicitud para buscar 'hands' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent4: Respuesta enviada al solicitante.
# Respuesta recibida de agent2_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 1 noticias para 'hands':
# - Myanmar quake toll passes 1,600 as people dig for survivors with bare hands
#
# Respuesta recibida de agent3_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'hands':
#
# Respuesta recibida de agent4_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'hands':
#
#
# --- Resumen de noticias de todos los agentes ---
# Desde agent2_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 1 noticias para 'hands':
# - Myanmar quake toll passes 1,600 as people dig for survivors with bare hands
#
# ------------------------------------------------
# Desde agent3_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'hands':
#
# ------------------------------------------------
# Desde agent4_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'hands':
#
# ------------------------------------------------
#
#
# Solicitud enviada a agent2_brivaro@gtirouter.dsic.upv.es.
# Solicitud enviada a agent3_brivaro@gtirouter.dsic.upv.es.
# Solicitud enviada a agent4_brivaro@gtirouter.dsic.upv.es.
# Agent2: Solicitud para buscar 'whisky' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent2: Respuesta enviada al solicitante.
# Agent3: Solicitud para buscar 'whisky' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent3: Respuesta enviada al solicitante.
# Agent4: Solicitud para buscar 'whisky' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent4: Respuesta enviada al solicitante.
# Respuesta recibida de agent2_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 1 noticias para 'whisky':
# - 'I used face recognition app to hunt man behind whisky fraud'
#
# Respuesta recibida de agent3_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'whisky':
#
# Respuesta recibida de agent4_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'whisky':
#
#
# --- Resumen de noticias de todos los agentes ---
# Desde agent2_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 1 noticias para 'whisky':
# - 'I used face recognition app to hunt man behind whisky fraud'
#
# ------------------------------------------------
# Desde agent3_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'whisky':
#
# ------------------------------------------------
# Desde agent4_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'whisky':
#
# ------------------------------------------------
#
#
# Solicitud enviada a agent2_brivaro@gtirouter.dsic.upv.es.
# Solicitud enviada a agent3_brivaro@gtirouter.dsic.upv.es.
# Solicitud enviada a agent4_brivaro@gtirouter.dsic.upv.es.
# Agent2: Solicitud para buscar 'victims' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent2: Respuesta enviada al solicitante.
# Agent3: Solicitud para buscar 'victims' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent3: Respuesta enviada al solicitante.
# Agent4: Solicitud para buscar 'victims' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent4: Respuesta enviada al solicitante.
# Respuesta recibida de agent2_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 2 noticias para 'victims':
# - 'I used face recognition app to hunt man behind whisky fraud'
# - Blood victims dying 'two a week' as thousands await compensation
#
# Respuesta recibida de agent3_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'victims':
#
# Respuesta recibida de agent4_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'victims':
#
#
# --- Resumen de noticias de todos los agentes ---
# Desde agent2_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 2 noticias para 'victims':
# - 'I used face recognition app to hunt man behind whisky fraud'
# - Blood victims dying 'two a week' as thousands await compensation
#
# ------------------------------------------------
# Desde agent3_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'victims':
#
# ------------------------------------------------
# Desde agent4_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'victims':
#
# ------------------------------------------------
#
#
# Solicitud enviada a agent2_brivaro@gtirouter.dsic.upv.es.
# Solicitud enviada a agent3_brivaro@gtirouter.dsic.upv.es.
# Solicitud enviada a agent4_brivaro@gtirouter.dsic.upv.es.
# Agent2: Solicitud para buscar 'dog' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent2: Respuesta enviada al solicitante.
# Agent3: Solicitud para buscar 'dog' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent3: Respuesta enviada al solicitante.
# Agent4: Solicitud para buscar 'dog' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent4: Respuesta enviada al solicitante.
# Respuesta recibida de agent2_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'dog':
#
# Respuesta recibida de agent3_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 1 noticias para 'dog':
# - Trump Order Could Cripple Federal Worker Unions Fighting DOGE Cuts
#
# Respuesta recibida de agent4_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'dog':
#
#
# --- Resumen de noticias de todos los agentes ---
# Desde agent2_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'dog':
#
# ------------------------------------------------
# Desde agent3_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 1 noticias para 'dog':
# - Trump Order Could Cripple Federal Worker Unions Fighting DOGE Cuts
#
# ------------------------------------------------
# Desde agent4_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'dog':
#
# ------------------------------------------------
#
#
# Solicitud enviada a agent2_brivaro@gtirouter.dsic.upv.es.
# Solicitud enviada a agent3_brivaro@gtirouter.dsic.upv.es.
# Solicitud enviada a agent4_brivaro@gtirouter.dsic.upv.es.
# Agent2: Solicitud para buscar '' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Ag
ent4_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 25 noticias para '':
# - Today's NYT Strands Hints, Answers and Help for March 30, #392
# - Today's NYT Connections Hints, Answers and Help for March 30, #658
# - Today's Wordle Hints, Answer and Help for March 30, #1380
# - The Final Season of 'The Righteous Gemstones' Is Here: When to Watch Episode 4 on Max
# - March Madness 2025: How to Watch the Elite Eight Today
# - I Get to Watch Disney Fireworks Every Day Thanks to My 3D Printer and Some Elbow Grease
# - 'The White Lotus' Season 3: When to Watch Episode 7 on Max
# - Waiting for a Recession to Buy a Home? This Realtor Weighs In
# - We Love This Hoto Laser Measuring Tool, and It's Now Down to $30 at Amazon's Big Spring Sale
# - How Many Microplastics Are You Eating? 10 Foods With More Than You Think
# - Watch FA Cup Soccer: Livestream Brighton vs. Nottingham Forest From Anywhere
# - Best Internet Providers in Winston-Salem, North Carolina
# - New Bambu H2D 3D Printer: Hype or Holy Grail? 50 Hours Later I'm Still Deciding
# - 'Suits LA': How to Watch Episode 6 of the Stephen Amell Spin-Off
# - Instagram Finally Lets You Play Reels at 2X Speed. Here's How to Do It
# - Are Protein Bars Actually Healthful? Experts Reveal Key Ingredients to Look For
# - Bundesliga Soccer Livestream: How to Watch Bayern Munich vs. St. Pauli From Anywhere
# - Act Now and Grab Kodak's Instant Photo Gear for Up to 28% Off During Amazon's Big Spring Sale
# - Here's When Your T-Mobile Data Breach Settlement Check Is Coming
# - Supreme Court Appears Reluctant to Eliminate Monthly Phone Fee
# - Sorry, DoorDash. I Will Not Be Financing My Pizza
# - Best Gas Grills of 2025
# - 23andMe Has Filed for Bankruptcy: 'Get Your Data out of There'
# - How to Watch March Madness Without Cable
# - Why Isn't My Internet Back Yet? The Hidden Challenges of Network Restoration
#
# ------------------------------------------------

# %%
html_content = """
<style>
    .title {
        font-size: 24px;
        font-weight: bold;
        color: #00aaff;
        text-align: center;
        margin-bottom: 10px;
    }
    .section {
        font-size: 18px;
        font-weight: bold;
        color: #000;
        background-color: #88ccff;
        padding: 5px;
        border-radius: 5px;
        margin-top: 10px;
    }
    .content {
        font-size: 16px;
        color: #000;
        line-height: 1.5;
        background-color: #eef;
        padding: 5px;
        border-radius: 5px;
    }
    .code {
        background-color: #222;
        padding: 10px;
        border-radius: 5px;
        font-family: monospace;
        color: #00ff00;
    }
</style>

<div class='title'>🕵️‍♂️ EJEMPLO 2: Agente 1 como Coordinador de Noticias 📰</div>

<div class='section'>🔍 ¿Qué hace este código?</div>
<div class='content'>
    Este código implementa un sistema multiagente en Python con SPADE donde <b>el Agente 1</b> actúa como un coordinador que solicita información de noticias a otros agentes (<b>Agente 2, Agente 3 y Agente 4</b>), los cuales consultan diferentes fuentes RSS.<br><br>
    <b>Flujo del programa:</b>
    <ul>
        <li>El usuario ingresa un término de búsqueda.</li>
        <li>El Agente 1 envía la solicitud a los otros tres agentes.</li>
        <li>Cada agente busca coincidencias en su respectivo feed RSS.</li>
        <li>Si encuentran noticias relevantes, las envían de vuelta al Agente 1.</li>
        <li>El Agente 1 recopila y muestra un resumen con los resultados obtenidos.</li>
        <li>Después de 1 minuto, todos los agentes se detienen automáticamente.</li>
    </ul>
</div>

<div class='section'>📌 Notas</div>
<div class='content'>
    - <b>Los agentes se detienen automáticamente</b> después de 1 minuto. <br/>
    - Si ningún agente encuentra coincidencias, simplemente se muestra un mensaje indicando que no hubo resultados. <br/>
    - Se puede extender este sistema para incluir más fuentes de noticias o mejorar la ontología utilizada.
</div>
"""

display(HTML(html_content))
# Out:
# <style>
#     .title {
#         font-size: 24px;
#         font-weight: bold;
#         color: #00aaff;
#         text-align: center;
#         margin-bottom: 10px;
#     }
#     .section {
#         font-size: 18px;
#         font-weight: bold;
#         color: #000;
#         background-color: #88ccff;
#         padding: 5px;
#         border-radius: 5px;
#         margin-top: 10px;
#     }
#     .content {
#         font-size: 16px;
#         color: #000;
#         line-height: 1.5;
#         background-color: #eef;
#         padding: 5px;
#         border-radius: 5px;
#     }
#     .code {
#         background-color: #222;
#         padding: 10px;
#         border-radius: 5px;
#         font-family: monospace;
#         color: #00ff00;
#     }
# </style>
#
# <div class='title'>🕵️‍♂️ EJEMPLO 2: Agente 1 como Coordinador de Noticias 📰</div>
#
# <div class='section'>🔍 ¿Qué hace este código?</div>
# <div class='content'>
#     Este código implementa un sistema multiagente en Python con SPADE donde <b>el Agente 1</b> actúa como un coordinador que solicita información de noticias a otros agentes (<b>Agente 2, Agente 3 y Agente 4</b>), los cuales consultan diferentes fuentes RSS.<br><br>
#     <b>Flujo del programa:</b>
#     <ul>
#         <li>El usuario ingresa un término de búsqueda.</li>
#         <li>El Agente 1 envía la solicitud a los otros tres agentes.</li>
#         <li>Cada agente busca coincidencias en su respectivo feed RSS.</li>
#         <li>Si encuentran noticias relevantes, las envían de vuelta al Agente 1.</li>
#         <li>El Agente 1 recopila y muestra un resumen con los resultados obtenidos.</li>
#         <li>Después de 1 minuto, todos los agentes se detienen automáticamente.</li>
#     </ul>
# </div>
#
# <div class='section'>📌 Notas</div>
# <div class='content'>
#     - <b>Los agentes se detienen automáticamente</b> después de 1 minuto. <br/>
#     - Si ningún agente encuentra coincidencias, simplemente se muestra un mensaje indicando que no hubo resultados. <br/>
#     - Se puede extender este sistema para incluir más fuentes de noticias o mejorar la ontología utilizada.
# </div>

# %%
# ---------------------------
# Agente 1: Coordinador e interfaz (solicita y resume resultados de 3 agentes)
# ---------------------------
class Agent1(Agent):
    async def setup(self):
        print(f"Agent1 iniciado: {self.jid}")
        self.add_behaviour(SearchAndCoordinateBehaviour())

class SearchAndCoordinateBehaviour(CyclicBehaviour):
    async def run(self):
        search_term = input("Ingrese la cadena de búsqueda de noticias: ")
        
        recipients = [
            "agent2_brivaro@gtirouter.dsic.upv.es",
            "agent3_brivaro@gtirouter.dsic.upv.es",
            "agent4_brivaro@gtirouter.dsic.upv.es" 
        ]
        
        responses = []
        
        for recipient in recipients:
            msg = Message(to=recipient)
            msg.set_metadata("performative", "request")
            msg.body = search_term
            await self.send(msg)
            print(f"Solicitud enviada a {recipient}.")

        # Esperar respuestas de cada agente (timeout 15 segundos)
        for _ in recipients:
            response = await self.receive(timeout=15)
            if response:
                responses.append((str(response.sender), response.body))
                print(f"Respuesta recibida de {response.sender}:")
                print(response.body)
            else:
                print("No se recibió respuesta en el tiempo esperado.")

        print("\n--- Resumen de noticias de todos los agentes ---")
        for sender, resp in responses:
            print(f"Desde {sender}:")
            print(resp)
            print("------------------------------------------------")
        print("\n")

        self.kill()

    async def on_end(self):
        print(f"Me las piro, vampiro :) soy el agente con JID: {self.agent.name}, y he terminado mi trabajo.")

# ---------------------------
# Agente base para buscadores que consulta un feed RSS y actualiza la ontología rNews
# ---------------------------
class BaseRSSAgent(Agent):
    def __init__(self, jid, password, feed_url, ontology_url, *args, **kwargs):
        super().__init__(jid, password, *args, **kwargs)
        self.feed_url = feed_url
        self.ontology_url = ontology_url

    async def setup(self):
        print(f"{self.__class__.__name__} iniciado: {self.jid}")
        try:
            self.onto = get_ontology(self.ontology_url).load()
            print(f"{self.__class__.__name__}: Ontología rNews cargada.")
        except Exception as e:
            print(f"{self.__class__.__name__}: Error al cargar la ontología:", e)
        
        # Registrar el comportamiento con un template que filtre mensajes con performative "request"
        template = Template(metadata={"performative": "request"})
        self.add_behaviour(RSSSearchBehaviour(self.feed_url), template)

# ---------------------------
# Comportamiento común para agentes que consultan un feed RSS
# ---------------------------
class RSSSearchBehaviour(CyclicBehaviour):
    def __init__(self, feed_url, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.feed_url = feed_url

    async def run(self):
        msg = await self.receive(timeout=10)
        if msg and msg.get_metadata("performative") == "request":
            search_term = msg.body
            print(f"{self.agent.__class__.__name__}: Solicitud para buscar '{search_term}' recibida de {msg.sender}")

            feed = feedparser.parse(self.feed_url)
            matching_entries = []
            for entry in feed.entries:
                # Buscar en el título o resumen (si existe)
                summary = entry.get("summary", "")
                if search_term.lower() in entry.title.lower() or search_term.lower() in summary.lower():
                    matching_entries.append(entry)

            result_text = f"Se encontraron {len(matching_entries)} noticias para '{search_term}':\n"
            for entry in matching_entries:
                result_text += f"- {entry.title}\n"

            # Preparar y enviar la respuesta
            reply = msg.make_reply()
            reply.set_metadata("performative", "inform")
            reply.body = result_text
            await self.send(reply)
            print(f"{self.agent.__class__.__name__}: Respuesta enviada al solicitante.")
        await asyncio.sleep(1)

# ---------------------------
# Agentes consultores (cada uno con un feed RSS distinto)
# ---------------------------
class Agent2(BaseRSSAgent):
    pass  # Usa la implementación base; su feed se definirá al instanciar

class Agent3(BaseRSSAgent):
    pass

class Agent4(BaseRSSAgent):
    pass

# %%
# ---------------------------
# Función principal para iniciar los agentes
# ---------------------------
password = "SPADE"

ontology_url = "http://dev.iptc.org/files/rNews/rnews_1.0_draft3_rdfxml.owl"

feed_url_agent2 = "http://feeds.bbci.co.uk/news/rss.xml"   # BBC News
feed_url_agent3 = "https://rss.nytimes.com/services/xml/rss/nyt/HomePage.xml"  # NYTimes
feed_url_agent4 = "https://www.cnet.com/rss/news/"  # CNET News

agent1_jid = "agent1_brivaro@gtirouter.dsic.upv.es"
agent2_jid = "agent2_brivaro@gtirouter.dsic.upv.es"
agent3_jid = "agent3_brivaro@gtirouter.dsic.upv.es"
agent4_jid = "agent4_brivaro@gtirouter.dsic.upv.es"

agent1 = Agent1(agent1_jid, password)
agent2 = Agent2(agent2_jid, password, feed_url_agent2, ontology_url)
agent3 = Agent3(agent3_jid, password, feed_url_agent3, ontology_url)
agent4 = Agent4(agent4_jid, password, feed_url_agent4, ontology_url)

await agent2.start(auto_register=True)
await agent3.start(auto_register=True)
await agent4.start(auto_register=True)
await asyncio.sleep(3) # Esperar un poco para asegurar que los agentes están listos
await agent1.start(auto_register=True)

print("Los agentes han comenzado. Se detendrán en 1 minuto...")

await asyncio.sleep(60)

print("Deteniendo los agentes...")
await agent1.stop()
await agent2.stop()
await agent3.stop()
await agent4.stop()
print("Agentes detenidos.")
# Out:
# Agent2 iniciado: agent2_brivaro@gtirouter.dsic.upv.es
# Agent2: Ontología rNews cargada.
# Agent3 iniciado: agent3_brivaro@gtirouter.dsic.upv.es
# Agent3: Ontología rNews cargada.
# Agent4 iniciado: agent4_brivaro@gtirouter.dsic.upv.es
# Agent4: Ontología rNews cargada.
# Agent1 iniciado: agent1_brivaro@gtirouter.dsic.upv.es
# Los agentes han comenzado. Se detendrán en 1 minuto...
# Solicitud enviada a agent2_brivaro@gtirouter.dsic.upv.es.
# Solicitud enviada a agent3_brivaro@gtirouter.dsic.upv.es.
# Solicitud enviada a agent4_brivaro@gtirouter.dsic.upv.es.
# Agent2: Solicitud para buscar 'survivors' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent2: Respuesta enviada al solicitante.
# Agent3: Solicitud para buscar 'survivors' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent3: Respuesta enviada al solicitante.
# Agent4: Solicitud para buscar 'survivors' recibida de agent1_brivaro@gtirouter.dsic.upv.es
# Agent4: Respuesta enviada al solicitante.
# Respuesta recibida de agent2_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 1 noticias para 'survivors':
# - Myanmar quake toll passes 1,600 as people dig for survivors with bare hands
#
# Respuesta recibida de agent3_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 2 noticias para 'survivors':
# - Myanmar Earthquake Toll Surpasses 1,600 Dead Amid Search for Survivors
# - Search for Survivors at Collapsed Bangkok Building
#
# Respuesta recibida de agent4_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'survivors':
#
#
# --- Resumen de noticias de todos los agentes ---
# Desde agent2_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 1 noticias para 'survivors':
# - Myanmar quake toll passes 1,600 as people dig for survivors with bare hands
#
# ------------------------------------------------
# Desde agent3_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 2 noticias para 'survivors':
# - Myanmar Earthquake Toll Surpasses 1,600 Dead Amid Search for Survivors
# - Search for Survivors at Collapsed Bangkok Building
#
# ------------------------------------------------
# Desde agent4_brivaro@gtirouter.dsic.upv.es:
# Se encontraron 0 noticias para 'survivors':
#
# ------------------------------------------------
#
#
# Me las piro, vampiro :) soy el agente con JID: agent1_brivaro, y he terminado mi trabajo.
# Deteniendo los agentes...
# Agentes detenidos.
